# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
Question1

# %%
def scrape_topRated_movies():
    response = requests.get("https://www.imdb.com/list/ls056092300/")
    print(response) 
    html_content = response.content
    

    soup = BeautifulSoup(html_content, "html.parser")
    top_movies = soup.find_all("div", class_="sc-b189961a-0 iqHBGn") #movies required info div

    movie_names=[]
    movie_ratings=[]
    movie_years=[]
    
    for movie in top_movies:
        movie_name = movie.find('h3', class_= "ipc-title__text").text
        movie_names.append(movie_name.strip())
        movie_rating = movie.find('span', class_= "ipc-rating-star--rating").text
        movie_ratings.append(movie_rating.strip)
        movie_year = movie.find('span', class_= "sc-b189961a-8").text
        movie_years.append(movie_year.strip())

   
    df = pd.DataFrame({
        "Movie Name": movie_names,
        "Rating": movie_ratings,
        "Year Of Release": movie_years
    })

    print(df)


scrape_topRated_movies()
# Out:
# <Response [403]>
# Empty DataFrame
# Columns: [Movie Name, Rating, Year Of Release]
# Index: []

# %%
question 2

# %%
def scrape_post_details():
    response = requests.get("https://www.patreon.com/coreyms")
    html_content = response.content
        
    soup = BeautifulSoup(html_content, "html.parser")
    posts = soup.find_all('span', class_="sc-fyrocj hwqvVN")
    print(posts)

scrape_post_details()
# Out:
# []

# %%
question 3

# %%
import requests
from bs4 import BeautifulSoup

def scrape_house_details(localities):
    
    url = "https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...&radius=2.0&city=bangalore&locality=Indiranagar,Jayanagar,Rajajinagar"

    response = requests.get(url)

    if response.status_code == 200:

        soup = BeautifulSoup(response.content, "html.parser")

        houses = soup.find_all("div", class_="infinite-scroll-component")

        for idx in range(100):
            id_val = "article_" + str(idx)
            for house in soup.find_all("article", id=id_val):
                try:

                    title = house.find("h2").text.strip()
                    location = house.find("div", class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0.1p po:max-w-95").text.strip()

                    price = house.find("div", class_="font-semi-bold heading-6").text.strip()
                    emi = house.find("div", id="roomType").text.strip()

                    print("Title:", title)
                    print("Location:", location)
                    print("EMI:", emi)
                    print("Price:", price)
                    print("-" * 50)
                except Exception as e:
                    print("Error:", e)
    else:
        print(f"Failed to fetch the page")

localities = ["Indira Nagar", "Jayanagar", "Rajaji Nagar"]

scrape_house_details(localities)
# Out:
# Title: 4+ BHK House For Sale  In Rajaji Nagar
# Location: Independent House, Lakshminarayanapuram,  near lakshmi jayam school
# EMI: ₹2.29 Lacs/Month
# Price: ₹4 Crores
# --------------------------------------------------
# Title: 4+ BHK House For Sale  In Rajajinagar
# Location: Independent House, 14th Main Rd near Athmeya polyclinic & Diagnostic Centre
# EMI: ₹74,508/Month
# Price: ₹1.3 Crores
# --------------------------------------------------
# Title: 2 BHK Flat In Sr Apartment For Sale  In Jayanagar
# Location: 11th main cross
# EMI: ₹42,985/Month
# Price: ₹75 Lacs
# --------------------------------------------------
# Title: 3 BHK House For Sale  In Rajajinagar
# Location: Independent House, Mahalaxmi Lyaout  near Pathacon Diagnostics
# EMI: ₹3.64 Lacs/Month
# Price: ₹6.35 Crores
# --------------------------------------------------
# Title: 2 BHK Apartment In  Habitat For Sale  In Rajajinagar
# Location: Habitat  14 th cross  1st block Rajajinagar bangalore-10
# EMI: ₹49,863/Month
# Price: ₹87 Lacs
# --------------------------------------------------
# Title: 2 BHK Flat In Ramya Regent For Sale  In Indiranagar
# Location: near police station
# EMI: ₹57,314/Month
# Price: ₹1 Crore
# --------------------------------------------------
# Title: 3 BHK Flat In Prospera Cerscent For Sale  In Indranagar Bangalore
# Location: 9th Main Road, 80 Feet Rd, opp. Canara Bank, HAL 2nd Stage, Indiranagar, Bengaluru, Karnataka 560008
# EMI: ₹1.09 Lacs/Month
# Price: ₹1.9 Crores
# --------------------------------------------------
# Title: 2 BHK Apartment In Uber Paxina, Jayanagar For Sale  In Jayanagar
# Location: Uber Paxina, Jayanagar   454, 7th Cross Rd, 6th Block, Jaya Nagar 1st Block, Jaya Nagar East, Hombegowda Nagar, Bengaluru, Karnataka 560011
# EMI: ₹91,703/Month
# Price: ₹1.6 Crores
# --------------------------------------------------
# Title: 3 BHK Apartment In Comfort Crissa For Sale  In Doddanekundi
# Location: Comfort Crissa  Comfort Crissa, 16th Cross Rd, Muniswamappa Layout, Vignan Nagar, Doddanekundi, Kaggadasapura, Bengaluru, Karnataka 560075
# EMI: ₹40,120/Month
# Price: ₹70 Lacs
# --------------------------------------------------
# Title: 2 BHK Flat In Pinnacle Appartment For Sale  In Rajajinagar
# Location: Subramanyanagar near Sir M Visvesvaraya Co-operative Bank Ltd
# EMI: ₹65,911/Month
# Price: ₹1.15 Crores
# --------------------------------------------------
# Title: 2 BHK Flat In Monolithic Apartments For Sale  In Nagapura
# Location: Monolithic ApartmentsRajajinagar, 132/A, 3rd Cross Rd, 1st R Block, Nagapura, Bengaluru, Karnataka 560010, India
# EMI: ₹28,084/Month
# Price: ₹49 Lacs
# --------------------------------------------------
# Title: 4 BHK Apartment In Brigade Gateway For Sale  In Rajajinagar
# Location: Brigade Gateway  Brigade Gateway Resident Ln, Rajajinagar, Bengaluru, Karnataka 560055
# EMI: ₹2.58 Lacs/Month
# Price: ₹4.5 Crores
# --------------------------------------------------
# Title: 2 BHK Flat In Syed Ghouse For Sale  In Jayanagar
# Location: 4th T Block East,Near Tilak English School
# EMI: ₹22,066/Month
# Price: ₹38.5 Lacs
# --------------------------------------------------
# Title: 2 BHK Flat In Blue Berry Apartment  For Sale  In  Indiranagar
# Location: 13th E Main Rd 8th cross, Paramahansa Yogananda Rd, Channakesahava Nagar, HAL 2nd Stage, Doopanahalli, Indiranagar, Bengaluru, Karnataka 560008, India
# EMI: ₹71,643/Month
# Price: ₹1.25 Crores
# --------------------------------------------------
# Title: 2 BHK Flat For Sale  In Jayanagar
# Location: Standalone Building, 22nd Cross Road, 3rd Block, Jayanagar, Jaya Nagar 1st Block, Jayanagar 3rd Block, Jayanagar, Bengaluru, Karnataka 560011, India
# EMI: ₹33,242/Month
# Price: ₹58 Lacs
# --------------------------------------------------
# Title: 3 BHK House For Sale  In Agrahara Dasarahalli
# Location: Independent House, near Shell petrol bunk and Raheja Apartments
# EMI: ₹71,643/Month
# Price: ₹1.25 Crores
# --------------------------------------------------
# Title: 3 BHK Flat In Chithaary Heights For Sale  In Bannerghatta Road
# Location: Jayanagar, Bangalore
# EMI: ₹54,448/Month
# Price: ₹95 Lacs
# --------------------------------------------------
# Title: 3 BHK Flat In Samrat Apartments For Sale  In Jayanagar
# Location: East End D Main Rd, Jayanagar, 9th Block, Bengaluru, Karnataka 560069, India
# EMI: ₹65,911/Month
# Price: ₹1.15 Crores
# --------------------------------------------------
# Title: 2 BHK Flat In South End Apartments, 73, Rv Road, Basavanagudi For Sale  In South End Circle
# Location: Kengeri Ring Road
# EMI: ₹54,448/Month
# Price: ₹95 Lacs
# --------------------------------------------------
# Title: 2 BHK Flat In Pooja Residency For Sale  In Indira Nagar
# Location: Indira Nagar, HAL 2nd Stage, Bangalore, Karnataka, INDIA
# EMI: ₹48,717/Month
# Price: ₹85 Lacs
# --------------------------------------------------
# Title: 4+ BHK House For Sale  In Rajajinagar 3rd Block
# Location: Independent House, Rajajinagar 3rd Block, Rajajinagar, Bengaluru, Karnataka 560010, India
# EMI: ₹3.87 Lacs/Month
# Price: ₹6.75 Crores
# --------------------------------------------------
# Title: 4+ BHK House For Sale  In Indira Nagar
# Location: Independent House, Hal 2nd Stage near Dr. Ambedkar College
# EMI: ₹6.3 Lacs/Month
# Price: ₹11 Crores
# --------------------------------------------------
# Title: 2 BHK Flat In Admiralty Manor For Sale  In Indiranagar
# Location: Admiralty Manor, 6th Main Rd, Eshwara Layout, Indiranagar, Bengaluru, Karnataka 560008, India
# EMI: ₹97,434/Month
# Price: ₹1.7 Crores
# --------------------------------------------------
# Title: 4+ BHK Apartment In Phoenix Kessaku For Sale  In Rajajinagar
# Location: Phoenix Kessaku  Opp. Vivekananda College,Dr Rajkumar Rd,Rajajinagar,Bangalore
# EMI: ₹6.41 Lacs/Month
# Price: ₹11.18 Crores
# --------------------------------------------------
# Title: 3 BHK Apartment In Phoenix Kessaku For Sale  In Rajajinagar
# Location: Phoenix Kessaku  Opp. Vivekananda College,Dr Rajkumar Rd, Rajajinagar,Bangalore
# EMI: ₹4.3 Lacs/Month
# Price: ₹7.5 Crores
# --------------------------------------------------
# Title: 4+ BHK House For Sale  In Rajaji Nagar
# Location: Independent House, Lakshminarayanapuram,  near lakshmi jayam school
# EMI: ₹2.29 Lacs/Month
# Price: ₹4 Crores
# --------------------------------------------------

# %%
question 4

# %%
page=requests.get('https://www.bewakoof.com/bestseller?sort=popular')
soup=BeautifulSoup(page.content)

Name=[]
price=[]
imageURL=[]

for i in soup.find_all('div',class_='productNaming bkf-ellipsis' ,limit=10):
    Name.append(i.text)

for i in soup.find_all('div',class_="discountedPriceText" ,limit=10):
    price.append(i.text)
    
for i in soup.find_all('img',class_='productImgTag' ,limit=10):
    imageURL.append(i.get('src'))
df=pd.DataFrame({'Name':Name,'Price':price, 'Image URL':imageURL})
df
# Out:
#                                                 Name Price  \
# 0  bewakoof x house of the dragonMen's Black Hous...  ₹399
# 1  Bewakoof®Women's White & Purple Camo Printed O...  ₹439
# 2  bewakoof x tom & jerryWomen's Blue Moody Jerry...  ₹499
# 3  bewakoof x tom & jerryWomen's Green Weirdos Fo...  ₹499
# 4  Bewakoof®Men's Black Warriors Graphic Printed ...  ₹499
# 5  Bewakoof®Women's Red Inner Peace Graphic Print...  ₹449
# 6            Bewakoof®Men's Sun-Kissed Green T-shirt  ₹499
# 7   Bewakoof®Men's Black Valhalla Typography T-shirt  ₹399
# 8  bewakoof x nasaMen's Red NASA Astronaut Graphi...  ₹499
# 9  bewakoof x tom & jerryWomen's Black Certified ...  ₹299
#
#                                            Image URL
# 0  https://images.bewakoof.com/t640/men-s-black-h...
# 1  https://images.bewakoof.com/t640/women-aop-ove...
# 2  https://images.bewakoof.com/t640/women-s-blue-...
# 3  https://images.bewakoof.com/t640/women-s-green...
# 4  https://images.bewakoof.com/t640/men-s-black-w...
# 5  https://images.bewakoof.com/t640/women-s-red-i...
# 6  https://images.bewakoof.com/t640/men-s-sun-kis...
# 7  https://images.bewakoof.com/t640/men-s-black-v...
# 8  https://images.bewakoof.com/t640/men-s-red-nas...
# 9  https://images.bewakoof.com/t640/women-s-black...

# %%
question 5

# %%
def scrape_news_details():
    #Fetch the content from the url
    response = requests.get("https://www.cnbc.com/world/?region=world")
    html_content = response.content
    #Use BeautifulSoup to parse the HTML
    soup = BeautifulSoup(html_content, "html.parser")
    headings = soup.find_all(['h1','h2','h3','h4','h5','h6'])
    all_news =  soup.find_all("div", class_= "LatestNews-headlineWrapper")

    #latest news and its details
    for news in all_news:
        news_heading = news.find("a",class_="LatestNews-headline").text
        date = news.find("time").text
        news_link = news.find("a",class_="LatestNews-headline")["href"]
        print(f"Heading: {news_heading}")
        print(f"Date: {date}")
        print(f"News link: {news_link}")
        print()
    
    print("In page Headings")
    #headings and its links
    for heading in headings:
        print(f"Heading: {heading.text}")
        heading_link = heading.find('a', href = True)
        if heading_link:
                print(f"Link: {heading_link['href']}")

#LatestNews-headlineWrapper class div
scrape_news_details()
# Out:
# Heading: Norfolk Southern board probing CEO Shaw over workplace relationship
# Date: 1 Hour Ago
# News link: https://www.cnbc.com/2024/09/08/norfolk-southern-nsc-alan-shaw-workplace-relationship.html
#
# Heading: Here are the three most important things to watch in the market this week
# Date: 4 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/here-are-the-three-most-important-things-to-watch-in-the-market-this-week.html
#
# Heading: Bernie Sanders: Harris' 28% capital gains tax proposal should be higher
# Date: 4 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/bernie-sanders-harris-capital-gains-tax-trump-election.html
#
# Heading: Reddit CEO shares the daily habit that's helped him succeed the most
# Date: 6 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/reddit-ceo-shares-the-daily-habit-thats-helped-him-succeed-the-most.html
#
# Heading: These 2 vacation splurges aren't worth it, says travel agent for billionaires
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/these-2-vacation-splurges-arent-worth-it-says-travel-agent-for-billionaires.html
#
# Heading: Amid AI boom, tech can't afford to neglect spending in these IT areas
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/amid-ai-boom-tech-cant-afford-to-neglect-spending-in-these-it-areas.html
#
# Heading: Why the father of 'life planning' says you're managing money the wrong way
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/how-life-planning-founder-george-kinder-thinks-you-should-manage-money.html
#
# Heading: The big risks of bitcoin ATMs
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/biggest-risks-of-accessing-crypto-through-bitcoin-atm.html
#
# Heading: Boeing and union reach a labor deal, potentially averting a strike
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/boeing-and-union-reach-a-labor-deal-potentially-averting-a-strike.html
#
# Heading: Suze Orman says 'everyone should absolutely' own bitcoin—here's why
# Date: 7 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/suze-orman-says-everyone-should-absolutely-own-bitcoin.html
#
# Heading: Leqembi could give Alzheimer's patients more time despite long road to treatment
# Date: 8 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/leqembi-alzheimers-patients-biogen-eisai.html
#
# Heading: Saudi investment minister touts 'green shoring' on path to diversification
# Date: 9 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/saudi-investment-minister-touts-green-shoring-on-path-to-diversification.html
#
# Heading: JPMorgan downgrades China, but still likes these individual stocks
# Date: 9 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/jpmorgan-downgrades-china-but-still-likes-these-individual-stocks.html
#
# Heading: Here's why Warren Buffett doesn't pay attention to macro factors when investing
# Date: 9 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/buffett-ignores-macro-factors-when-investing-heres-why.html
#
# Heading: Ether has dramatically underperformed bitcoin as its investment case weakens
# Date: 9 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/ether-has-dramatically-underperformed-bitcoin-as-its-investment-case-weakens.html
#
# Heading: As consumers trade down to private label brands, these stocks could head up
# Date: 9 Hours Ago
# News link: https://www.cnbc.com/2024/09/08/as-consumers-trade-down-to-cheaper-private-label-brands-these-stocks-could-head-up.html
#
# Heading: Yellen says U.S. economy remains solid, on path to 'soft landing' with no meaningful layoffs
# Date: 21 Hours Ago
# News link: https://www.cnbc.com/2024/09/07/yellen-says-us-economy-remains-solid-heading-toward-soft-landing.html
#
# Heading: CIA director: There was risk of Russia using nuclear weapon early in Ukraine war
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/cia-director-russia-ukraine-war-nuclear-weapon-risk.html
#
# Heading: Divorce parties reached an all-time high last year: 'It was incredibly therapeutic'
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/divorce-parties-reached-an-all-time-high-last-year-heres-why.html
#
# Heading: 3 ways Wall Street's largest banks are leveraging AI to increase profitability
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/3-ways-wall-street-largest-banks-are-leveraging-ai-to-increase-profitability.html
#
# Heading: This luxury psilocybin retreat 'creates better leaders,' founders say
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/this-luxury-psilocybin-retreat-creates-better-leaders-founders-say.html
#
# Heading: Top 2 U.S. cities to retire are in Florida—No. 3 is nearly 1,800 miles away
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/wallethub-best-us-cities-to-retire.html
#
# Heading: YouTube group The Try Guys quickly found success in launching subscription model
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/the-try-guys-has-quickly-found-success-in-launching-subscription-model.html
#
# Heading: CEO quit his job, bought a snack company for $250K—now it brings in $103M/year
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/lesserevil-ceo-why-i-left-wall-street-for-a-failing-snack-company.html
#
# Heading: 'The starving artist' is a myth, author says: How creatives sustain a career
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/stacey-derasmo-what-it-takes-for-creatives-to-sustain-a-career.html
#
# Heading: Bill Gates wants to work another 20 to 30 years, like his friend Warren Buffett
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/bill-gates-retirement-sounds-awful-ill-work-like-warren-buffett.html
#
# Heading: Bull market limps into 2-year birthday with soft economic landing in doubt
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/bull-market-limps-into-2-year-birthday-with-soft-economic-landing-in-doubt-and-stock-leaders-failing.html
#
# Heading: Small nuclear reactors could power the future — the challenge is getting one built
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/how-small-modular-reactors-could-expand-nuclear-power-in-the-us.html
#
# Heading: This gym stock is a buy because of pickleball surge, says Bank of America
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/buy-this-gym-stock-because-of-popular-pickleball-says-bank-of-america.html
#
# Heading: The U.S. colleges with the happiest students—Apple CEO Tim Cook went to No. 1
# Date: September 7, 2024
# News link: https://www.cnbc.com/2024/09/07/colleges-with-the-happiest-student.html
#
# In page Headings
# Heading: Many 'doubted the vision': Saudi investment minister touts 'green shoring' on path to diversification
# Link: https://www.cnbc.com/2024/09/08/saudi-investment-minister-touts-green-shoring-on-path-to-diversification.html
# Heading: Latest News
# Heading: QUOTE FINDER
# Heading: Markets
# Link: //www.cnbc.com/us-market-movers/
# Heading: Market MOVERS
# Link: /us-market-movers/
# Heading: Most Active
# Heading: Unusual Volume
# Heading: Latest Market News
# Link: /stocks/
# Heading: Special Reports
# Heading: Trending Now
# Heading: Pro News and Analysis
# Link: https://www.cnbc.com/pro/news/
# Heading: UK Votes
# Link: https://www.cnbc.com/uk-votes/
# Heading: Sustainable Future
# Link: https://www.cnbc.com/sustainable-future/
# Heading: CNBC Travel
# Link: https://www.cnbc.com/cnbc-travel/
# Heading: Make It
# Link: https://www.cnbc.com/make-it/
# Heading: CNBC Explains
# Link: https://www.cnbc.com/cnbc-explains/
# Heading: News Tips
# Heading: CNBC Newsletters
# Heading: Advertise With Us

# %%
question 6

# %%
def find_article_details():
    #Fetch the content from the url
    response = requests.get("https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/")
    html_content = response.content
    
    #Use BeautifulSoup to parse the HTML
    soup = BeautifulSoup(html_content, "html.parser")
    articles = soup.find_all("div", class_= "article-listing")
    
    for article in articles:
        title = article.find('h2', class_= "h5 article-title").find("a").text
        date = article.find('p', class_= "article-date").text
        author = article.find('p', class_= "article-authors").text
        print(f"Paper Title: {title.strip()}")
        print(f"Date: {date}")
        print(f"Author: {author.strip()}")
        print('')

find_article_details()
# Out:
# Paper Title: Implementation of artificial intelligence in agriculture for optimisation of irrigation and application of pesticides and herbicides
# Date: 2020
# Author: Tanha Talaviya |  Dhara Shah |  Nivedita Patel |  Hiteshri Yagnik |  Manan Shah
#
# Paper Title: Review of agricultural IoT technology
# Date: 2022
# Author: Jinyuan Xu |  Baoxing Gu |  Guangzhao Tian
#
# Paper Title: Automation and digitization of agriculture using artificial intelligence and internet of things
# Date: 2021
# Author: A. Subeesh |  C.R. Mehta
#
# Paper Title: A comprehensive review on automation in agriculture using artificial intelligence
# Date: June 2019
# Author: Kirtan Jha |  Aalap Doshi |  Poojan Patel |  Manan Shah
#
# Paper Title: Applications of electronic nose (e-nose) and electronic tongue (e-tongue) in food quality-related properties determination: A review
# Date: 2020
# Author: Juzhong Tan |  Jie Xu
#
# Paper Title: Towards sustainable agriculture: Harnessing AI for global food security
# Date: June 2024
# Author: Dhananjay K. Pandey |  Richa Mishra
#
# Paper Title: Fruit ripeness classification: A survey
# Date: March 2023
# Author: Matteo Rizzo |  Matteo Marcuzzo |  Alessandro Zangari |  Andrea Gasparetto |  Andrea Albarelli
#
# Paper Title: Deep learning based computer vision approaches for smart agricultural applications
# Date: 2022
# Author: V.G. Dhanya |  A. Subeesh |  N.L. Kushwaha |  Dinesh Kumar Vishwakarma |  T. Nagesh Kumar |  G. Ritika |  A.N. Singh
#
# Paper Title: A review of imaging techniques for plant disease detection
# Date: 2020
# Author: Vijai Singh |  Namita Sharma |  Shikha Singh
#
# Paper Title: Transfer Learning for Multi-Crop Leaf Disease Image Classification using Convolutional Neural Network VGG
# Date: 2022
# Author: Ananda S. Paymode |  Vandana B. Malode
#
# Paper Title: Comparison of CNN-based deep learning architectures for rice diseases classification
# Date: September 2023
# Author: Md Taimur Ahad |  Yan Li |  Bo Song |  Touhid Bhuiyan
#
# Paper Title: DeepRice: A deep learning and deep feature based classification of Rice leaf disease subtypes
# Date: March 2024
# Author: P. Isaac Ritharson |  Kumudha Raimond |  X. Anitha Mary |  Jennifer Eunice Robert |  Andrew J
#
# Paper Title: Computer vision in smart agriculture and precision farming: Techniques and applications
# Date: September 2024
# Author: Sumaira Ghazal |  Arslan Munir |  Waqar S. Qureshi
#
# Paper Title: Image classification on smart agriculture platforms: Systematic literature review
# Date: September 2024
# Author: Juan Felipe Restrepo-Arias |  John W. Branch-Bedoya |  Gabriel Awad
#
# Paper Title: Using an improved lightweight YOLOv8 model for real-time detection of multi-stage apple fruit in complex orchard environments
# Date: March 2024
# Author: Baoling Ma |  Zhixin Hua |  Yuchen Wen |  Hongxing Deng |  Yongjie Zhao |  Liuru Pu |  Huaibo Song
#
# Paper Title: How artificial intelligence uses to achieve the agriculture sustainability: Systematic review
# Date: June 2023
# Author: Vilani Sachithra |  L.D.C.S. Subhashini
#
# Paper Title: LeafSpotNet: A deep learning framework for detecting leaf spot disease in jasmine plants
# Date: June 2024
# Author: Shwetha V |  Arnav Bhagwat |  Vijaya Laxmi
#
# Paper Title: Plant disease detection using hybrid model based on convolutional autoencoder and convolutional neural network
# Date: 2021
# Author: Punam Bedi |  Pushkar Gole
#
# Paper Title: Cross-comparative review of Machine learning for plant disease detection: apple, cassava, cotton and potato plants
# Date: June 2024
# Author: James Daniel Omaye |  Emeka Ogbuju |  Grace Ataguba |  Oluwayemisi Jaiyeoba |  Joseph Aneke |  Francisca Oladipo
#
# Paper Title: A comprehensive survey on weed and crop classification using machine learning and deep learning
# Date: September 2024
# Author: Faisal Dharma Adhinata |   Wahyono |  Raden Sumiharto
#
# Paper Title: A systematic review of machine learning techniques for cattle identification: Datasets, methods and future directions
# Date: 2022
# Author: Md Ekramul Hossain |  Muhammad Ashad Kabir |  Lihong Zheng |  Dave L. Swain |  Shawn McGrath |  Jonathan Medway
#
# Paper Title: Machine learning in nutrient management: A review
# Date: September 2023
# Author: Oumnia Ennaji |  Leonardus Vergütz |  Achraf El Allali
#
# Paper Title: Deep convolutional neural network models for weed detection in polyhouse grown bell peppers
# Date: 2022
# Author: A. Subeesh |  S. Bhole |  K. Singh |  N.S. Chandel |  Y.A. Rajwade |  K.V.R. Rao |  S.P. Kumar |  D. Jat
#
# Paper Title: A review on computer vision systems in monitoring of poultry: A welfare perspective
# Date: 2020
# Author: Cedric Okinda |  Innocent Nyalala |  Tchalla Korohou |  Celestine Okinda |  Jintao Wang |  Tracy Achieng |  Patrick Wamalwa |  Tai Mang |  Mingxia Shen
#
# Paper Title: Explainable artificial intelligence and interpretable machine learning for agricultural data analysis
# Date: 2022
# Author: Masahiro Ryo
